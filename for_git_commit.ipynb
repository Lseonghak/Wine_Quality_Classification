# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !git remote rm origin

# %%
# !echo "# Wine_Quality_Classification" >> README.md
# !git init
# !git config --global user.email "dltjdgkr6220@gmail.com"
# !git config --global user.name "Lseonghak"
# !git add README.md
# !git add .
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://Lseonghak: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@github.com/Lseonghak/Wine_Quality_Classification.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/.git/
# [main 103dc8f] first commit
#  1 file changed, 1 insertion(+)
# Counting objects: 33, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (26/26), done.
# Writing objects: 100% (33/33), 8.42 MiB | 2.19 MiB/s, done.
# Total 33 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), done.
# To https://github.com/Lseonghak/Wine_Quality_Classification.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
